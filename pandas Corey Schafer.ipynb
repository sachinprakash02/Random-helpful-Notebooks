# %%
import pandas as pd

# %% [markdown]
# #### Video 1 : Getting Started

# %%
# to set the maximum number of columns to be displayed in df:
pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',100)

# %% [markdown]
# #### Video 2 : DataFrame and Series

# %%
# Dataframe Structure :

people = {
    "first":["Sachin","Rohit","Jay"],
    "last":["Prakash","kumar","Pathak"],
    "email":["xyz.com","abc.in",'klm.us']
}

# %%
people["first"][2]
# Out:
# 'Jay'

# %%
df = pd.read_csv('survey_results_public.csv')
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
# ...

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df["Hobbyist"].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df.loc[0:3,"Hobbyist":"Country"]
# Out:
#   Hobbyist   Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# 0      Yes   NaN         13  Monthly        NaN            NaN
# 1       No   NaN         19      NaN        NaN            NaN
# 2      Yes   NaN         15      NaN        NaN            NaN
# 3      Yes  25.0         18      NaN        NaN            NaN
#
#               Country
# 0             Germany
# 1      United Kingdom
# 2  Russian Federation
# 3             Albania

# %% [markdown]
# #### Video 3 : indexes

# %%
df_sample = pd.DataFrame(people)

# %%
df_sample.set_index('email',inplace=True)
df_sample
# Out:
#           first     last
# email
# xyz.com  Sachin  Prakash
# abc.in    Rohit    kumar
# klm.us      Jay   Pathak

# %%
df_sample.loc['xyz.com','last']
# Out:
# 'Prakash'

# %%
df_sample.reset_index(inplace=True)
df_sample
# Out:
#    index    email   first     last
# 0      0  xyz.com  Sachin  Prakash
# 1      1   abc.in   Rohit    kumar
# 2      2   klm.us     Jay   Pathak

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
# ...

# %% [markdown]
# #### Video 4 : Filtering

# %%
df_sample["last"] == "Prakash" # True whereever it matches the criteria.
# Out:
# 0     True
# 1    False
# 2    False
# Name: last, dtype: bool

# %%
df_sample = pd.DataFrame(people)

# %%
filter_var = df_sample["last"] == "Prakash" # can use & and | conditions between filter conditions.
df_sample[filter_var]
# Out:
#     first     last    email
# 0  Sachin  Prakash  xyz.com

# %%
df_sample.loc[filter_var,"email"]
# Out:
# 0    xyz.com
# Name: email, dtype: object

# %%
countries = ["India","Germany"]
filter_var = df["Country"].isin(countries)
df.loc[filter_var,["Country","Age"]].head()
# Out:
#     Country   Age
# 0   Germany   NaN
# 5   Germany   NaN
# 6     India   NaN
# 21    India   NaN
# 22  Germany  27.0

# %%
filter_var = df["LanguageWorkedWith"].str.contains("Python",na=False)
df.loc[filter_var,["LanguageWorkedWith"]].head()
# Out:
#                                   LanguageWorkedWith
# 2                           Objective-C;Python;Swift
# 7                                         Python;SQL
# 9                HTML/CSS;Java;JavaScript;Python;SQL
# 12                               C;JavaScript;Python
# 14  Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL

# %% [markdown]
# #### Video 5 :Updating Rows and Columns

# %%
df_sample.columns = ["First Name","Last Name","email"] # Renaming 
df_sample
# Out:
#   First Name Last Name    email
# 0     Sachin   Prakash  xyz.com
# 1      Rohit     kumar   abc.in
# 2        Jay    Pathak   klm.us

# %%
df_sample.rename(columns={"First Name":"First_Name"},inplace=True)
df_sample
# Out:
#   First_Name Last Name    email
# 0     Sachin   Prakash  xyz.com
# 1      Rohit     kumar   abc.in
# 2        Jay    Pathak   klm.us

# %%
# updating data in rows :
df_sample.loc[1] = ["Rohit","Kr","abc.in"]
df_sample
# Out:
#   First_Name Last Name    email
# 0     Sachin   Prakash  xyz.com
# 1      Rohit        Kr   abc.in
# 2        Jay    Pathak   klm.us

# %%
df_sample.loc[2,["email"]] = ["abc.com"]
df_sample
# Out:
#   First_Name Last Name    email
# 0     Sachin   Prakash  xyz.com
# 1      Rohit        Kr   abc.in
# 2        Jay    Pathak  abc.com

# %%
df_sample.at[2,2] = "abc.org"
df_sample
# Out:
#   First_Name Last Name    email        2
# 0     Sachin   Prakash  xyz.com      NaN
# 1      Rohit        Kr   abc.in      NaN
# 2        Jay    Pathak  abc.com  abc.org

# %%
df_sample = df_sample.drop(columns=2)
df_sample
# Out:
#   First_Name Last Name    email
# 0     Sachin   Prakash  xyz.com
# 1      Rohit        Kr   abc.in
# 2        Jay    Pathak  abc.com

# %%
df_sample = df_sample["email"].str.upper()
df_sample
# Out:
# 0    XYZ.COM
# 1     ABC.IN
# 2    ABC.COM
# Name: email, dtype: object

# %%
df_sample = pd.DataFrame(people)

# %%
df_sample["email"] = df_sample["email"].str.upper()
df_sample
# Out:
#     first     last    email
# 0  Sachin  Prakash  XYZ.COM
# 1   Rohit    kumar   ABC.IN
# 2     Jay   Pathak   KLM.US

# %%
df_sample["email"].apply(len) # to apply formula
# Out:
# 0    7
# 1    6
# 2    6
# Name: email, dtype: int64

# %%
df_sample.apply(pd.Series.min)
# Out:
# first       Jay
# last     Pathak
# email    ABC.IN
# dtype: object

# %%
# to apply a function to entire df:
df_sample.applymap(len)
# Out:
#    first  last  email
# 0      6     7      7
# 1      5     5      6
# 2      3     6      6

# %%
df_sample['first'] = df_sample['first'].map({'Sachin':'Sach','Rohit':'Rht','Jay':'J'})
df_sample['first']
# Out:
# 0    Sach
# 1     Rht
# 2       J
# Name: first, dtype: object

# %% [markdown]
# #### Video 6 : Adding Removing Column

# %%
df_sample = pd.DataFrame(people)

# %%
df_sample["full name"] = df_sample["first"] + ' ' + df_sample["last"]
df_sample
# Out:
#     first     last    email       full name
# 0  Sachin  Prakash  xyz.com  Sachin Prakash
# 1   Rohit    kumar   abc.in     Rohit kumar
# 2     Jay   Pathak   klm.us      Jay Pathak

# %%
df_sample.drop(columns=["first","last"],inplace=True)

# %%
df_sample
# Out:
#      email       full name
# 0  xyz.com  Sachin Prakash
# 1   abc.in     Rohit kumar
# 2   klm.us      Jay Pathak

# %%
df_sample["full name"].str.split(' ',expand=True)
# Out:
#         0        1
# 0  Sachin  Prakash
# 1   Rohit    kumar
# 2     Jay   Pathak

# %%
df_sample[["first","last"]] = df_sample["full name"].str.split(' ',expand=True) # expand = true splits it in 2 separate cols

# %%
df_sample
# Out:
#      email       full name (first, last)   first     last
# 0  xyz.com  Sachin Prakash        Sachin  Sachin  Prakash
# 1   abc.in     Rohit kumar         Rohit   Rohit    kumar
# 2   klm.us      Jay Pathak           Jay     Jay   Pathak

# %%
df_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
# email            3 non-null object
# full name        3 non-null object
# (first, last)    3 non-null object
# first            3 non-null object
# last             3 non-null object
# dtypes: object(5)
# memory usage: 200.0+ bytes

# %%
#adding rows

# %%
df_sample.append({"first":"Guddu"},ignore_index=True)
# Out:
#      email       full name (first, last)   first     last
# 0  xyz.com  Sachin Prakash        Sachin  Sachin  Prakash
# 1   abc.in     Rohit kumar         Rohit   Rohit    kumar
# 2   klm.us      Jay Pathak           Jay     Jay   Pathak
# 3      NaN             NaN           NaN   Guddu      NaN

# %%
df1 = pd.DataFrame(people)

# %%
heros = {'first':['Tony','Steve'],
        'last':['Stark','Rogers']
        }
df2 = pd.DataFrame(heros)
df2
# Out:
#    first    last
# 0   Tony   Stark
# 1  Steve  Rogers

# %%
df1 = df1.append(df2,ignore_index=True)
df1
# Out:
#      email   first     last
# 0  xyz.com  Sachin  Prakash
# 1   abc.in   Rohit    kumar
# 2   klm.us     Jay   Pathak
# 3      NaN    Tony    Stark
# 4      NaN   Steve   Rogers

# %%
df1.drop(index=1,inplace=True) # dropping index

# %%
df1.drop(index=df1[df1["last"] == "Rogers"].index)
# Out:
#      email   first     last
# 0  xyz.com  Sachin  Prakash
# 2   klm.us     Jay   Pathak
# 3      NaN    Tony    Stark

# %% [markdown]
# #### Video 8 : Gropuing and Aggregating

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
#      CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# ...

# %%
df["ConvertedComp"].median()
# Out:
# 54049.0

# %%
df.median() # runs over numeric feilds.
# Out:
# Respondent       32231.0
# Age                 29.0
# CompTotal        63000.0
# ConvertedComp    54049.0
# WorkWeekHrs         40.0
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
# Respondent                      64461 non-null int64
# MainBranch                      64162 non-null object
# Hobbyist                        64416 non-null object
# Age                             45446 non-null float64
# Age1stCode                      57900 non-null object
# CompFreq                        40069 non-null object
# CompTotal                       34826 non-null float64
# ConvertedComp                   34756 non-null float64
# Country                         64072 non-null object
# CurrencyDesc                    45472 non-null object
# CurrencySymbol                  45472 non-null object
# DatabaseDesireNextYear          44070 non-null object
# DatabaseWorkedWith              49537 non-null object
# DevType                         49370 non-null object
# EdLevel                         57431 non-null object
# ...

# %%
df["Country"].value_counts(normalize=True)
# Out:
# United States                         0.194609
# India                                 0.131149
# United Kingdom                        0.060807
# Germany                               0.060713
# Canada                                0.034196
# France                                0.029623
# Brazil                                0.028374
# Netherlands                           0.020961
# Poland                                0.019946
# Australia                             0.018854
# Spain                                 0.018120
# Italy                                 0.017434
# Russian Federation                    0.017043
# Sweden                                0.013828
# Pakistan                              0.012626
# Turkey                                0.012127
# Israel                                0.010192
# Switzerland                           0.009817
# Bangladesh                            0.009505
# Romania                               0.009427
# ...

# %%
# using group by :
# Split -> Apply -> Combine.

df.groupby(["Country"])

# %%
df.groupby(["Country"]).get_group("India").head()
# Out:
#      Respondent                              MainBranch Hobbyist   Age  \
# 6             7          I am a developer by profession      Yes   NaN
# 21           22          I am a developer by profession      Yes   NaN
# 57           58          I am a developer by profession      Yes   NaN
# 62           63  I am a student who is learning to code      Yes  21.0
# 147         149          I am a developer by profession      Yes  36.0
#
#     Age1stCode CompFreq   CompTotal  ConvertedComp Country  \
# 6           18  Monthly         NaN            NaN   India
# 21          18  Monthly         NaN            NaN   India
# 57          22      NaN         NaN            NaN   India
# 62          17      NaN         NaN            NaN   India
# 147         31   Yearly  21000000.0       293196.0   India
#
#              CurrencyDesc CurrencySymbol      DatabaseDesireNextYear  \
# 6    United States dollar            USD                         NaN
# ...

# %%
df.groupby(["Country"])["Age"].value_counts()
# Out:
# Country      Age
# Afghanistan  23.0     5
#              22.0     3
#              25.0     3
#              15.0     2
#              20.0     2
#              24.0     2
#              28.0     2
#              26.0     1
#              30.0     1
#              32.0     1
# Albania      23.0     4
#              22.0     3
#              25.0     3
#              28.0     3
#              38.0     3
#              24.0     2
#              33.0     2
#              16.0     1
#              18.0     1
#              19.0     1
#              21.0     1
#              26.0     1
#              27.0     1
#              29.0     1
#              31.0     1
#              34.0     1
#              37.0     1
# Algeria      23.0     6
#              26.0     6
#              24.0     4
#              25.0     4
#              20.0     3
#              27.0     3
#              28.0     3
#              29.0     3
#              21.0     2
#              22.0     2
# ...

# %%
df.groupby(["Country"])["Age"].value_counts().loc["India"] # using .loc to work on indexes
# Out:
# Age
# 23.0    424
# 25.0    407
# 24.0    380
# 26.0    341
# 22.0    339
# 27.0    298
# 21.0    294
# 28.0    282
# 30.0    258
# 29.0    232
# 20.0    209
# 19.0    127
# 31.0    123
# 32.0    103
# 18.0     82
# 33.0     76
# 35.0     71
# 34.0     47
# 36.0     35
# 38.0     35
# 17.0     30
# 16.0     27
# 40.0     27
# 39.0     23
# 15.0     22
# 37.0     22
# 41.0     13
# 42.0      9
# 48.0      9
# 43.0      8
# 44.0      8
# 13.0      6
# 14.0      6
# 45.0      6
# 55.0      4
# 46.0      2
# 54.0      2
# 57.0      2
# 99.0      2
# 3.0       1
# 7.0       1
# 10.0      1
# 11.0      1
# 12.0      1
# 19.8      1
# 21.5      1
# 24.5      1
# 26.5      1
# 47.0      1
# 50.0      1
# 51.0      1
# 52.0      1
# 59.0      1
# 60.0      1
# 61.0      1
# 63.0      1
# 69.0      1
# 70.0      1
# 73.0      1
# 94.0      1
# 98.0      1
# Name: Age, dtype: int64

# %%
df.groupby(["Country"])["ConvertedComp"].agg(["median","mean"]).head()
# Out:
#               median         mean
# Country
# Afghanistan  15163.5  148290.1250
# Albania      15900.0   25611.0000
# Algeria       9432.0   10362.8125
# Andorra      88640.0   88640.0000
# Angola        5292.0    5292.0000

# %%
df.groupby(["Country"])["LanguageWorkedWith"].apply(lambda x : x.str.contains("Python").sum())
# Out:
# Country
# Afghanistan                                    11
# Albania                                        13
# Algeria                                        40
# Andorra                                         3
# Angola                                          1
# Antigua and Barbuda                             0
# Argentina                                     134
# Armenia                                        17
# Australia                                     524
# Austria                                       205
# Azerbaijan                                     11
# Bahamas                                         1
# Bahrain                                         2
# Bangladesh                                    179
# Barbados                                        2
# Belarus                                        40
# Belgium                                       173
# Belize                                          2
# Benin                                           3
# ...

# %%
country_respondents = df["Country"].value_counts()
country_respondents
# Out:
# United States                         12469
# India                                  8403
# United Kingdom                         3896
# Germany                                3890
# Canada                                 2191
# France                                 1898
# Brazil                                 1818
# Netherlands                            1343
# Poland                                 1278
# Australia                              1208
# Spain                                  1161
# Italy                                  1117
# Russian Federation                     1092
# Sweden                                  886
# Pakistan                                809
# Turkey                                  777
# Israel                                  653
# Switzerland                             629
# Bangladesh                              609
# Romania                                 604
# Nigeria                                 593
# ...

# %%
python_respondents = df.groupby(["Country"])["LanguageWorkedWith"].apply(lambda x : x.str.contains("Python").sum())

# %%
python_df = pd.concat([country_respondents,python_respondents],axis="columns",sort=False)
python_df.head()
# Out:
#                 Country  LanguageWorkedWith
# United States     12469                5964
# India              8403                2670
# United Kingdom     3896                1621
# Germany            3890                1712
# Canada             2191                1011

# %%
python_df.loc["India"]
# Out:
# Country               8403
# LanguageWorkedWith    2670
# Name: India, dtype: int64

# %%
print(python_df.loc["India"].Country)
# Out:
# 8403

# %% [markdown]
# #### Video 9 : Data Cleaning

# %%
import numpy as np
people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}
df3 = pd.DataFrame(people)
df3
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df3.dropna() # removes 3,4,5 rows
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %%
df3.dropna(axis='index',how="any") # same as above ; how = "all" ,
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %%
df3.dropna(axis="columns",how="all")
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df3.dropna(axis="index",how="any",subset=["email"]) # dropping from specific column
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df3.replace("NA",np.nan,inplace=True) # replacing a paticular occurance

# %%
df3.replace("Missing",np.nan,inplace=True)

# %%
df3
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      Anonymous@email.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
df3.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %%
df3.fillna("MISSING") # filling np.nan with "MISSING"
# Out:
#      first     last                    email      age
# 0    Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1     Jane      Doe        JaneDoe@email.com       55
# 2     John      Doe        JohnDoe@email.com       63
# 3    Chris  Schafer                  MISSING       36
# 4  MISSING  MISSING                  MISSING  MISSING
# 5  MISSING  MISSING      Anonymous@email.com  MISSING
# 6  MISSING  MISSING                  MISSING  MISSING

# %%
# type casting :
df3.dtypes
# Out:
# first    object
# last     object
# email    object
# age      object
# dtype: object

# %%
type(np.nan)
# Out:
# float

# %%
df3["age"].fillna(0,inplace=True) # or directly type cast to float since np.nan is float

# %%
df3["age"] =df3["age"].astype('int')

# %%
df3.dtypes
# Out:
# first    object
# last     object
# email    object
# age       int32
# dtype: object

# %%
df3["age"] =df3["age"].astype('float')
df3.dtypes
# Out:
# first     object
# last      object
# email     object
# age      float64
# dtype: object

# %%
df3
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33.0
# 1   Jane      Doe        JaneDoe@email.com  55.0
# 2   John      Doe        JohnDoe@email.com  63.0
# 3  Chris  Schafer                     None  36.0
# 4    NaN      NaN                      NaN   0.0
# 5   None      NaN      Anonymous@email.com   0.0
# 6    NaN      NaN                      NaN   0.0

# %%
df3["age"].median()
# Out:
# 33.0

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
df.YearsCode.head()
# Out:
# 0    36
# 1     7
# 2     4
# 3     7
# 4    15
# Name: YearsCode, dtype: object

# %%
df["YearsCode"].dtype
# Out:
# dtype('O')

# %%
df["YearsCode"].unique()
# Out:
# array(['36', '7', '4', '15', '6', '17', '8', '10', '35', '5', '37', '19',
#        '9', '22', '30', '23', '20', '2', 'Less than 1 year', '3', '13',
#        '25', '16', '43', '11', '38', '33', nan, '24', '21', '12', '40',
#        '27', '50', '46', '14', '18', '28', '32', '44', '26', '42', '31',
#        '34', '29', '1', '39', '41', '45', 'More than 50 years', '47',
#        '49', '48'], dtype=object)

# %%
# there are mixed of values here!

# %%
df["YearsCode"].replace('Less than 1 year',0,inplace=True)

# %%
df["YearsCode"].replace('More than 50 years',51,inplace=True)

# %%
df["YearsCode"] = df["YearsCode"].astype("float")

# %%
df["YearsCode"].mean()
# Out:
# 12.709052770265584

# %% [markdown]
# #### Video 10 : Date Time Analysis

# %%
df = pd.read_csv('ETH_1hr.csv')
df.head()
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
df.loc[0,"Date"]
# Out:
# '2020-03-13 08-PM'

# %%
# https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior

# %%
d_parser = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %I-%p')
df = pd.read_csv('ETH_1hr.csv', parse_dates=['Date'], date_parser=d_parser)

# %%
df.loc[0,"Date"]
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
df.loc[0,"Date"].day_name()
# Out:
# 'Friday'

# %%
df["Date"].dt.day_name().head()
# Out:
# 0    Friday
# 1    Friday
# 2    Friday
# 3    Friday
# 4    Friday
# Name: Date, dtype: object

# %%
df["DayOfWeek"] = df["Date"].dt.day_name()

# %%
df.head()
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume  \
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
#
#   DayOfWeek
# 0    Friday
# 1    Friday
# 2    Friday
# 3    Friday
# 4    Friday

# %%
filt = (df["Date"] >= pd.to_datetime('2019-01-01')) & (df["Date"] <= '2020')
df.loc[filt].shape
# Out:
# (8761, 8)

# %%
df.set_index("Date",inplace=True)

# %%
df['2019':'2020-03'].head()
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
#
#                     DayOfWeek
# Date
# 2020-03-13 20:00:00    Friday
# 2020-03-13 19:00:00    Friday
# 2020-03-13 18:00:00    Friday
# 2020-03-13 17:00:00    Friday
# 2020-03-13 16:00:00    Friday

# %%
# Resampling :

# %%
df["High"].resample('D')
# Out:
# DatetimeIndexResampler [freq=<Day>, axis=0, closed=left, label=left, convention=start, base=0]

# %%
highs = df["High"].resample('D').max()

# %%
highs['2020-01-01']
# Out:
# 132.68
